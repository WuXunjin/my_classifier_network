# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 1000)  
y = np.sin(x)  
plt.figure(figsize=(8,4)) 
plt.plot(x,y,label="sinx",color="red",linewidth=2)  
plt.xlabel("Time(s)")  
plt.ylabel("Volt")  
plt.title("PyPlot First Example")  
plt.ylim(-1.2,1.2)  
plt.show()

# %%
T = np.array([6, 7, 8, 9, 10, 11, 12])  
power = np.array([1.53E+03, 5.92E+02, 2.04E+02, 7.24E+01, 2.72E+01, 1.10E+01, 4.70E+00])  
  
plt.plot(T,power)  
plt.show()

# %%
N = 10
x = np.random.randn(N)
y = np.random.randn(N)
plt.scatter(x, y)
plt.show()

# %%
print '我暂时只要做到这个样子就好了'
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
type1=ax.scatter(0,0,c='r')
type2=ax.scatter(1,1,c='g')
ax.legend(handles = [type1, type2,], labels = ['red', 'green'], loc = 'best')
# Out:
# 我暂时只要做到这个样子就好了

# %%
print '下面试试动态图'
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import numpy as np
import math
    
plt.close()  #clf() # 清图  cla() # 清坐标轴 close() # 关窗口
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.axis("equal") #设置图像显示的时候XY轴比例
plt.grid(True) #添加网格
plt.ion()  #interactive mode on
IniObsX=40
IniObsY=40
IniObsAngle=135
IniObsSpeed=10*math.sqrt(2)   #米/秒
print('开始仿真')
for t in range(19):
    print('epoch%d'%t)
    #障碍物船只轨迹
    obsX=t+1
    obsY=t+1
    ax.scatter(obsX,obsY,c='b',marker='.')  #散点图
    #ax.lines.pop(1)  #删除轨迹
    #下面的图,两船的距离
    plt.pause(0.001)
# Out:
# 下面试试动态图
# 开始仿真
# epoch0
# epoch1
# epoch2
# epoch3
# epoch4
# epoch5
# epoch6
# epoch7
# epoch8
# epoch9
# epoch10
# epoch11
# epoch12
# epoch13
# epoch14
# epoch15
# epoch16
# epoch17
# epoch18

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import numpy as np
import math
fig=plt.figure()
ax_loss=fig.add_subplot(1,2,1)
plt.title('loss')
plt.xlabel("epoch") 
ax_acc=fig.add_subplot(1,2,2)
plt.title('acc')
plt.xlabel("epoch")  
ax_loss.grid(True) #添加网格
ax_acc.grid(True) #添加网格
for i in range(10):
    ax_loss.scatter(i,np.random.randn(1),c='r')
    print '我去  %d'%i
# Out:
# 我去  0
# 我去  1
# 我去  2
# 我去  3
# 我去  4
# 我去  5
# 我去  6
# 我去  7
# 我去  8
# 我去  9

# %%
from PIL import Image
img_path='/home/kimy/data_sets/VOCdevkit/2012/VOC2012/JPEGImages/2007_000032.jpg'
img = Image.open(img_path).convert('RGB')
plt.imshow(img)
a=img.resize((56,56))
plt.figure()
plt.imshow(a)

# %%
a='asdasdfdege%d  %d'
print a%(1,2)
# Out:
# asdasdfdege1  2
